# %%
import os
import h5py
from glob import glob
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal
data_dir='~/Data/'
import numpy
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)


# make sure we're dealing with the most recent version of any code we're using
# %load_ext autoreload
# %autoreload 2
# %cd ~/Data/
# %pwd
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /home/jovyan/Data
# '/home/jovyan/Data'

# %%
# %pwd

filename = 'processed_ATL07-01_20181202120647_09910101_001_01.h5'
# See what is in a particular file
# !h5ls -r processed_ATL07-01_20181202120647_09910101_001_01.h5
# Out:
# /                        Group
# /METADATA                Group
# /METADATA/AcquisitionInformation Group
# /METADATA/AcquisitionInformation/lidar Group
# /METADATA/AcquisitionInformation/lidarDocument Group
# /METADATA/AcquisitionInformation/platform Group
# /METADATA/AcquisitionInformation/platformDocument Group
# /METADATA/DataQuality    Group
# /METADATA/DataQuality/CompletenessOmission Group
# /METADATA/DataQuality/DomainConsistency Group
# /METADATA/DatasetIdentification Group
# /METADATA/Extent         Group
# /METADATA/Lineage        Group
# /METADATA/Lineage/ANC02-02 Group
# /METADATA/Lineage/ANC15  Group
# /METADATA/Lineage/ANC19  Group
# /METADATA/Lineage/ANC25-07 Group
# /METADATA/Lineage/ANC26-07 Group
# /METADATA/Lineage/ANC31  Group
# /METADATA/Lineage/ANC36-07 Group
# /METADATA/Lineage/ANC38-07 Group
# /METADATA/Lineage/ATL03  Group
# /METADATA/Lineage/ATL09  Group
# /METADATA/Lineage/Control Group
# /METADATA/ProcessStep    Group
# /METADATA/ProcessStep/Browse Group
# /METADATA/ProcessStep/Metadata Group
# /METADATA/ProcessStep/PGE Group
# /METADATA/ProcessStep/QA Group
# /METADATA/ProductSpecificationDocument Group
# /METADATA/QADatasetIdentification Group
# /METADATA/SeriesIdentification Group
# /gt1l                    Group
# /gt1l/sea_ice_segments   Group
# /gt1l/sea_ice_segments/delta_time Dataset {225054/Inf}
# /gt1l/sea_ice_segments/geophysical Group
# /gt1l/sea_ice_segments/geophysical/height_segment_dac Dataset {225054/Inf}
# /gt1l/sea_ice_segments/geophysical/height_segment_geoid Dataset {225054/Inf}
# /gt1l/sea_ice_segments/geophysical/height_segment_mss Dataset {225054/Inf}
# /gt1l/sea_ice_segments/heights Group
# /gt1l/sea_ice_segments/heights/across_track_distance Dataset {225054/Inf}
# /gt1l/sea_ice_segments/heights/height_segment_confidence Dataset {225054/Inf}
# /gt1l/sea_ice_segments/heights/height_segment_fit_quality_flag Dataset {225054/Inf}
# /gt1l/sea_ice_segments/heights/height_segment_height Dataset {225054/Inf}
# /gt1l/sea_ice_segments/heights/height_segment_length_seg Dataset {225054/Inf}
# /gt1l/sea_ice_segments/heights/height_segment_rms Dataset {225054/Inf}
# /gt1l/sea_ice_segments/heights/height_segment_ssh_flag Dataset {225054/Inf}
# /gt1l/sea_ice_segments/heights/height_segment_surface_error_est Dataset {225054/Inf}
# /gt1l/sea_ice_segments/heights/height_segment_type Dataset {225054/Inf}
# /gt1l/sea_ice_segments/heights/height_segment_w_gaussian Dataset {225054/Inf}
# /gt1l/sea_ice_segments/latitude Dataset {225054/Inf}
# /gt1l/sea_ice_segments/longitude Dataset {225054/Inf}
# /gt1l/sea_ice_segments/seg_dist_x Dataset {225054/Inf}
# /gt1l/sea_ice_segments/stats Group
# /gt1l/sea_ice_segments/stats/ice_conc Dataset {225054/Inf}
# /gt1r                    Group
# /gt1r/sea_ice_segments   Group
# /gt1r/sea_ice_segments/delta_time Dataset {227904/Inf}
# /gt1r/sea_ice_segments/geophysical Group
# /gt1r/sea_ice_segments/geophysical/height_segment_dac Dataset {227904/Inf}
# /gt1r/sea_ice_segments/geophysical/height_segment_geoid Dataset {227904/Inf}
# /gt1r/sea_ice_segments/geophysical/height_segment_mss Dataset {227904/Inf}
# /gt1r/sea_ice_segments/heights Group
# /gt1r/sea_ice_segments/heights/across_track_distance Dataset {227904/Inf}
# /gt1r/sea_ice_segments/heights/height_segment_confidence Dataset {227904/Inf}
# /gt1r/sea_ice_segments/heights/height_segment_fit_quality_flag Dataset {227904/Inf}
# /gt1r/sea_ice_segments/heights/height_segment_height Dataset {227904/Inf}
# /gt1r/sea_ice_segments/heights/height_segment_length_seg Dataset {227904/Inf}
# /gt1r/sea_ice_segments/heights/height_segment_rms Dataset {227904/Inf}
# /gt1r/sea_ice_segments/heights/height_segment_ssh_flag Dataset {227904/Inf}
# /gt1r/sea_ice_segments/heights/height_segment_surface_error_est Dataset {227904/Inf}
# /gt1r/sea_ice_segments/heights/height_segment_type Dataset {227904/Inf}
# /gt1r/sea_ice_segments/heights/height_segment_w_gaussian Dataset {227904/Inf}
# /gt1r/sea_ice_segments/latitude Dataset {227904/Inf}
# /gt1r/sea_ice_segments/longitude Dataset {227904/Inf}
# /gt1r/sea_ice_segments/seg_dist_x Dataset {227904/Inf}
# /gt1r/sea_ice_segments/stats Group
# /gt1r/sea_ice_segments/stats/ice_conc Dataset {227904/Inf}
# /gt2l                    Group
# /gt2l/sea_ice_segments   Group
# /gt2l/sea_ice_segments/delta_time Dataset {178857/Inf}
# /gt2l/sea_ice_segments/geophysical Group
# /gt2l/sea_ice_segments/geophysical/height_segment_dac Dataset {178857/Inf}
# /gt2l/sea_ice_segments/geophysical/height_segment_geoid Dataset {178857/Inf}
# /gt2l/sea_ice_segments/geophysical/height_segment_mss Dataset {178857/Inf}
# /gt2l/sea_ice_segments/heights Group
# /gt2l/sea_ice_segments/heights/across_track_distance Dataset {178857/Inf}
# /gt2l/sea_ice_segments/heights/height_segment_confidence Dataset {178857/Inf}
# /gt2l/sea_ice_segments/heights/height_segment_fit_quality_flag Dataset {178857/Inf}
# /gt2l/sea_ice_segments/heights/height_segment_height Dataset {178857/Inf}
# /gt2l/sea_ice_segments/heights/height_segment_length_seg Dataset {178857/Inf}
# /gt2l/sea_ice_segments/heights/height_segment_rms Dataset {178857/Inf}
# /gt2l/sea_ice_segments/heights/height_segment_ssh_flag Dataset {178857/Inf}
# /gt2l/sea_ice_segments/heights/height_segment_surface_error_est Dataset {178857/Inf}
# /gt2l/sea_ice_segments/heights/height_segment_type Dataset {178857/Inf}
# /gt2l/sea_ice_segments/heights/height_segment_w_gaussian Dataset {178857/Inf}
# /gt2l/sea_ice_segments/latitude Dataset {178857/Inf}
# /gt2l/sea_ice_segments/longitude Dataset {178857/Inf}
# /gt2l/sea_ice_segments/seg_dist_x Dataset {178857/Inf}
# /gt2l/sea_ice_segments/stats Group
# /gt2l/sea_ice_segments/stats/ice_conc Dataset {178857/Inf}
# /gt2r                    Group
# /gt2r/sea_ice_segments   Group
# /gt2r/sea_ice_segments/delta_time Dataset {181780/Inf}
# /gt2r/sea_ice_segments/geophysical Group
# /gt2r/sea_ice_segments/geophysical/height_segment_dac Dataset {181780/Inf}
# /gt2r/sea_ice_segments/geophysical/height_segment_geoid Dataset {181780/Inf}
# /gt2r/sea_ice_segments/geophysical/height_segment_mss Dataset {181780/Inf}
# /gt2r/sea_ice_segments/heights Group
# /gt2r/sea_ice_segments/heights/across_track_distance Dataset {181780/Inf}
# /gt2r/sea_ice_segments/heights/height_segment_confidence Dataset {181780/Inf}
# /gt2r/sea_ice_segments/heights/height_segment_fit_quality_flag Dataset {181780/Inf}
# /gt2r/sea_ice_segments/heights/height_segment_height Dataset {181780/Inf}
# /gt2r/sea_ice_segments/heights/height_segment_length_seg Dataset {181780/Inf}
# /gt2r/sea_ice_segments/heights/height_segment_rms Dataset {181780/Inf}
# /gt2r/sea_ice_segments/heights/height_segment_ssh_flag Dataset {181780/Inf}
# /gt2r/sea_ice_segments/heights/height_segment_surface_error_est Dataset {181780/Inf}
# /gt2r/sea_ice_segments/heights/height_segment_type Dataset {181780/Inf}
# /gt2r/sea_ice_segments/heights/height_segment_w_gaussian Dataset {181780/Inf}
# /gt2r/sea_ice_segments/latitude Dataset {181780/Inf}
# /gt2r/sea_ice_segments/longitude Dataset {181780/Inf}
# /gt2r/sea_ice_segments/seg_dist_x Dataset {181780/Inf}
# /gt2r/sea_ice_segments/stats Group
# /gt2r/sea_ice_segments/stats/ice_conc Dataset {181780/Inf}
# /gt3l                    Group
# /gt3l/sea_ice_segments   Group
# /gt3l/sea_ice_segments/delta_time Dataset {232176/Inf}
# /gt3l/sea_ice_segments/geophysical Group
# /gt3l/sea_ice_segments/geophysical/height_segment_dac Dataset {232176/Inf}
# /gt3l/sea_ice_segments/geophysical/height_segment_geoid Dataset {232176/Inf}
# /gt3l/sea_ice_segments/geophysical/height_segment_mss Dataset {232176/Inf}
# /gt3l/sea_ice_segments/heights Group
# /gt3l/sea_ice_segments/heights/across_track_distance Dataset {232176/Inf}
# /gt3l/sea_ice_segments/heights/height_segment_confidence Dataset {232176/Inf}
# /gt3l/sea_ice_segments/heights/height_segment_fit_quality_flag Dataset {232176/Inf}
# /gt3l/sea_ice_segments/heights/height_segment_height Dataset {232176/Inf}
# /gt3l/sea_ice_segments/heights/height_segment_length_seg Dataset {232176/Inf}
# /gt3l/sea_ice_segments/heights/height_segment_rms Dataset {232176/Inf}
# /gt3l/sea_ice_segments/heights/height_segment_ssh_flag Dataset {232176/Inf}
# /gt3l/sea_ice_segments/heights/height_segment_surface_error_est Dataset {232176/Inf}
# /gt3l/sea_ice_segments/heights/height_segment_type Dataset {232176/Inf}
# /gt3l/sea_ice_segments/heights/height_segment_w_gaussian Dataset {232176/Inf}
# /gt3l/sea_ice_segments/latitude Dataset {232176/Inf}
# /gt3l/sea_ice_segments/longitude Dataset {232176/Inf}
# /gt3l/sea_ice_segments/seg_dist_x Dataset {232176/Inf}
# /gt3l/sea_ice_segments/stats Group
# /gt3l/sea_ice_segments/stats/ice_conc Dataset {232176/Inf}
# /gt3r                    Group
# /gt3r/sea_ice_segments   Group
# /gt3r/sea_ice_segments/delta_time Dataset {235280/Inf}
# /gt3r/sea_ice_segments/geophysical Group
# /gt3r/sea_ice_segments/geophysical/height_segment_dac Dataset {235280/Inf}
# /gt3r/sea_ice_segments/geophysical/height_segment_geoid Dataset {235280/Inf}
# /gt3r/sea_ice_segments/geophysical/height_segment_mss Dataset {235280/Inf}
# /gt3r/sea_ice_segments/heights Group
# /gt3r/sea_ice_segments/heights/across_track_distance Dataset {235280/Inf}
# /gt3r/sea_ice_segments/heights/height_segment_confidence Dataset {235280/Inf}
# /gt3r/sea_ice_segments/heights/height_segment_fit_quality_flag Dataset {235280/Inf}
# /gt3r/sea_ice_segments/heights/height_segment_height Dataset {235280/Inf}
# /gt3r/sea_ice_segments/heights/height_segment_length_seg Dataset {235280/Inf}
# /gt3r/sea_ice_segments/heights/height_segment_type Dataset {235280/Inf}
# /gt3r/sea_ice_segments/heights/height_segment_w_gaussian Dataset {235280/Inf}
# /gt3r/sea_ice_segments/latitude Dataset {235280/Inf}
# /gt3r/sea_ice_segments/longitude Dataset {235280/Inf}
# /gt3r/sea_ice_segments/seg_dist_x Dataset {235280/Inf}
# /gt3r/sea_ice_segments/stats Group
# /gt3r/sea_ice_segments/stats/ice_conc Dataset {235280/Inf}

# %%
# %pwd

namer = ['gt1r','gt1l','gt2r','gt2l','gt3r','gt3l']
print(namer)

f = h5py.File(filename, 'r')


[xval,conc,lat,lon,SSH,qual,pgram] = ([] for i in range(7))

for x in range(len(namer)):
    
    # Load in all beams
    xval.append(f[namer[x] + '/sea_ice_segments/seg_dist_x'][:] - f[namer[x] + '/sea_ice_segments/seg_dist_x'][0]) 
    conc.append(f[namer[x] + '/sea_ice_segments/stats/ice_conc'][:])
    lat.append(f[namer[x] + '/sea_ice_segments/latitude'][:])
    lon.append(f[namer[x] + '/sea_ice_segments/longitude'][:])
    SSH.append(f[namer[x] + '/sea_ice_segments/heights/height_segment_height'][:])
    qual.append(f[namer[x] + '/sea_ice_segments/heights/height_segment_fit_quality_flag'][:])
    
xbuckets = numpy.logspace(0, 5, num=20, endpoint=False, base=10.0, dtype=None)
    
for x in range(6):
    
    good = qual[x]>0
    yvec = lat[x][good]
    xvec = xval[x][good]
    
    pgram.append(scipy.signal.lombscargle(xvec,yvec,xbuckets))
            
    plt.loglog(xbuckets,pgram[x])    

plt.xlabel('Length Scale')      
plt.ylabel('PSD')
plt.legend(namer)
        
    
#plt.scatter(lat,SSH,c=qual); plt.colorbar()
# Out:
# ['gt1r', 'gt1l', 'gt2r', 'gt2l', 'gt3r', 'gt3l']

# %%
good = qual > 1; 
yvec = SSH[good]
xvec = lat[good]
xbuckets = numpy.logspace(1, 5, num=25, endpoint=False, base=10.0, dtype=None)
pgram = scipy.signal.lombscargle(xvec,yvec,xbuckets)
plt.loglog(xbuckets,pgram)
