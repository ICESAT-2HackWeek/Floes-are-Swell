# %% [markdown]
# # Obtain ATL010 Data from NSIDC DAAC - spatially/temporally subsetted to Bering Sea

# %% [markdown]
# ## Import packages

# %%
import requests
import getpass
import socket
import json
import zipfile
import io
import math
import os
import shutil
import pprint
import time
import geopandas as gpd
import matplotlib.pyplot as plt
import fiona
import h5py
import re
# To read KML files with geopandas, we will need to enable KML support in fiona (disabled by default)
fiona.drvsupport.supported_drivers['LIBKML'] = 'rw'
from shapely.geometry import Polygon, mapping
from shapely.geometry.polygon import orient
from statistics import mean
from requests.auth import HTTPBasicAuth

# %%
# Earthdata Login credentials

# Enter your Earthdata Login user name
uid = 'axel_schweiger'
# Enter your email address associated with your Earthdata Login account
email = 'schweig@uw.edu'
pswd = getpass.getpass('Earthdata Login password: ')
# Out:
# Earthdata Login password:  ··········

# %%
# Request token from Common Metadata Repository using Earthdata credentials
token_api_url = 'https://cmr.earthdata.nasa.gov/legacy-services/rest/tokens'
hostname = socket.gethostname()
ip = socket.gethostbyname(hostname)

data = {
    'token': {
        'username': uid,
        'password': pswd,
        'client_id': 'NSIDC_client_id',
        'user_ip_address': ip
    }
}
headers={'Accept': 'application/json'}
response = requests.post(token_api_url, json=data, headers=headers)
token = json.loads(response.content)['token']['id']
print(token)
# Out:
# E62B4B88-9593-546B-D952-510D17894DA3

# %%
# Input data set ID (e.g. ATL07) of interest here, also known as "short name".
# We're gonna do this with the sea ice product. 
short_name = 'ATL10'
latest_version = '001'

# %%
# Input temporal range 

# Input start date in yyyy-MM-dd format
start_date = '2018-12-01'
# Input start time in HH:mm:ss format
start_time = '00:00:00'
# Input end date in yyyy-MM-dd format
end_date = '2018-12-06'
# Input end time in HH:mm:ss format
end_time = '23:59:59'

temporal = start_date + 'T' + start_time + 'Z' + ',' + end_date + 'T' + end_time + 'Z'
print(temporal)
# Out:
# 2018-12-01T00:00:00Z,2018-12-06T23:59:59Z

# %%
# # Commenting for tutorial since we will be walking through option 3 (spatial file input) together
# # Bounding Box spatial parameter in 'W,S,E,N' format

# Input bounding box
# Input lower left longitude in decimal degrees
LL_lon = '-180'
# Input lower left latitude in decimal degrees
LL_lat = '60'
# Input upper right longitude in decimal degrees
UR_lon = '-160'
# Input upper right latitude in decimal degrees
UR_lat = '85'
# aoi value used for CMR params below

bounding_box = LL_lon + ',' + LL_lat + ',' + UR_lon + ',' + UR_lat
bbox = bounding_box
# aoi value used for CMR params below
aoi = '1'
print(bounding_box)
# Out:
# -180,60,-160,85

# %%
params = {
    'short_name': short_name,
    'version': latest_version,
    'temporal': temporal,
    'page_size': 100,
    'page_num': 1,
    'bounding_box': bounding_box
    }
    
# Query number of granules using our (paging over results)

granule_search_url = 'https://cmr.earthdata.nasa.gov/search/granules'

granules = []
while True:
    response = requests.get(granule_search_url, params=params, headers=headers)
    results = json.loads(response.content)

    if len(results['feed']['entry']) == 0:
        # Out of results, so break out of loop
        break

    # Collect results and increment page_num
    granules.extend(results['feed']['entry'])
    params['page_num'] += 1

    
# Get number of granules over my area and time of interest
len(granules)
# Out:
# 30

# %%
# Query service capability URL 

from xml.etree import ElementTree as ET

capability_url = f'https://n5eil02u.ecs.nsidc.org/egi/capabilities/{short_name}.{latest_version}.xml'

print(capability_url)
# Out:
# https://n5eil02u.ecs.nsidc.org/egi/capabilities/ATL10.001.xml

# %% [markdown]
# All of NSIDC's service endpoints are behind NASA Earthdata Login. We need to create a session to store cookies and pass Earthdata Login credentials to capabilities url.

# %%
# Create session to store cookie and pass credentials to capabilities url

session = requests.session()
s = session.get(capability_url)
response = session.get(s.url,auth=(uid,pswd))

root = ET.fromstring(response.content)

# %% [markdown]
# From the service capability XML, we can collect lists with each service option to gather service information.

# %%
# collect lists with each service option

subagent = [subset_agent.attrib for subset_agent in root.iter('SubsetAgent')]

# variable subsetting
variables = [SubsetVariable.attrib for SubsetVariable in root.iter('SubsetVariable')]  
variables_raw = [variables[i]['value'] for i in range(len(variables))]
variables_join = [''.join(('/',v)) if v.startswith('/') == False else v for v in variables_raw] 
variable_vals = [v.replace(':', '/') for v in variables_join]

# reformatting
formats = [Format.attrib for Format in root.iter('Format')]
format_vals = [formats[i]['value'] for i in range(len(formats))]
format_vals.remove('')

# reprojection only applicable on ICESat-2 L3B products, yet to be available. 

# reformatting options that support reprojection
normalproj = [Projections.attrib for Projections in root.iter('Projections')]
normalproj_vals = []
normalproj_vals.append(normalproj[0]['normalProj'])
format_proj = normalproj_vals[0].split(',')
format_proj.remove('')
format_proj.append('No reformatting')

#reprojection options
projections = [Projection.attrib for Projection in root.iter('Projection')]
proj_vals = []
for i in range(len(projections)):
    if (projections[i]['value']) != 'NO_CHANGE' :
        proj_vals.append(projections[i]['value'])
        
# reformatting options that do not support reprojection
no_proj = [i for i in format_vals if i not in format_proj]

# %% [markdown]
# #### Let's confirm that subset services exist for our data set by reviewing the `subagent` list. If the list contains service information, we know that services are available. If not, we need to set the `agent` API parameter to `NO` to indicate that our request will bypass the subsetter. This will quickly send back the data "natively" without any customization applied.

# %%
print(subagent)
if len(subagent) < 1 :
    agent = 'NO'
# Out:
# [{'id': 'ICESAT2', 'spatialSubsetting': 'true', 'spatialSubsettingShapefile': 'true', 'temporalSubsetting': 'true', 'type': 'both', 'maxGransSyncRequest': '100', 'maxGransAsyncRequest': '2000'}]

# %% [markdown]
# More information is contained in the subagent list, including the maximum number of granules that we can request per order depending on our configuration. We'll come back to these options below.

# %% [markdown]
# #### Let's start with spatial subsetting. Recall that there are three options to *filter* our search results by spatial constraint:
#
# 1) Bounding Box: Corresponding to the CMR `bounding_box` KVP
#
# 2) Polygon coordinate pairs: Corresponding to the CMR `polygon` KVP
#
# 3) Spatial file input, including Esri Shapefile or KML/KMZ: We simplified the file input to also be read by the CMR `polygon` KVP
#
# #### We see above that `spatialSubsetting` is `true` and `spatialSubsettingShapefile` is `true`. Therefore the same *filtering* options can be applied to our *subset* constraint, with unique KVPs for the subsetting service:
#
# 1) Bounding Box: `bbox` subset KVP
#
# 2) Polygon coordinate pairs: `bounding_shape` subset KVP in [GeoJSON](https://geojson.org/) format.
#
# 3) Spatial file input: The file can be read directly by the subsetter without simplification. This file will be posted to the API endpoint, so we don't need to specify an additional subset KVP here.

# %% [markdown]
# #### Because we're pursuing option 3), we don't need to provide an additional subset parameter. Below is commented code for bounding box inputs.

# %%
# Temporal subsetting KVP

timevar = start_date + 'T' + start_time + ',' + end_date + 'T' + end_time
print(timevar)

print(format_vals)
pprint.pprint(variable_vals)
# Out:
# 2018-12-01T00:00:00,2018-12-06T23:59:59
# ['NetCDF-3', 'NetCDF4-CF', 'TABULAR_ASCII']
# ['/ancillary_data',
#  '/ancillary_data/atlas_sdp_gps_epoch',
#  '/ancillary_data/control',
#  '/ancillary_data/data_end_utc',
#  '/ancillary_data/data_start_utc',
#  '/ancillary_data/end_cycle',
#  '/ancillary_data/end_delta_time',
#  '/ancillary_data/end_geoseg',
#  '/ancillary_data/end_gpssow',
#  '/ancillary_data/end_gpsweek',
#  '/ancillary_data/end_orbit',
#  '/ancillary_data/end_region',
#  '/ancillary_data/end_rgt',
#  '/ancillary_data/granule_end_utc',
#  '/ancillary_data/granule_start_utc',
#  '/ancillary_data/release',
#  '/ancillary_data/start_cycle',
#  '/ancillary_data/start_delta_time',
#  '/ancillary_data/start_geoseg',
#  '/ancillary_data/start_gpssow',
#  '/ancillary_data/start_gpsweek',
#  '/ancillary_data/start_orbit',
#  '/ancillary_data/start_region',
#  '/ancillary_data/start_rgt',
#  '/ancillary_data/version',
#  '/ancillary_data/freeboard_estimation',
#  '/ancillary_data/freeboard_estimation/b_fr',
#  '/ancillary_data/freeboard_estimation/fbswath_fb_hist_max',
#  '/ancillary_data/freeboard_estimation/fbswath_fb_hist_min',
#  '/ancillary_data/freeboard_estimation/fill_height_pct',
#  '/ancillary_data/freeboard_estimation/fill_snow_depth',
#  '/ancillary_data/freeboard_estimation/fill_ub_width',
#  '/ancillary_data/freeboard_estimation/height_segment_fit_quality_flag_max',
#  '/ancillary_data/freeboard_estimation/height_segment_fit_quality_flag_min',
#  '/ancillary_data/freeboard_estimation/ht_thresh1',
#  '/ancillary_data/freeboard_estimation/ht_thresh2',
#  '/ancillary_data/freeboard_estimation/ic_thresh1',
#  '/ancillary_data/freeboard_estimation/ic_thresh2',
#  '/ancillary_data/freeboard_estimation/l',
#  '/ancillary_data/freeboard_estimation/lb_n_f',
#  '/ancillary_data/freeboard_estimation/maxgapht',
#  '/ancillary_data/freeboard_estimation/maxgaptime',
#  '/ancillary_data/freeboard_estimation/min_land_dist',
#  '/ancillary_data/freeboard_estimation/multi_beam_disable_flag',
#  '/ancillary_data/freeboard_estimation/n_fillpass',
#  '/ancillary_data/freeboard_estimation/refsurf_h_offset1',
#  '/ancillary_data/freeboard_estimation/refsurf_h_offset2',
#  '/ancillary_data/freeboard_estimation/refsurf_sd_fill',
#  '/ancillary_data/freeboard_estimation/refsurf_slope_fill',
#  '/ancillary_data/freeboard_estimation/refsurf_slope_ub',
#  '/freeboard_swath_segment',
#  '/freeboard_swath_segment/delta_time',
#  '/freeboard_swath_segment/ds_si_hist_bins',
#  '/freeboard_swath_segment/fbswath_fb_height',
#  '/freeboard_swath_segment/fbswath_fb_hist',
#  '/freeboard_swath_segment/fbswath_fb_length',
#  '/freeboard_swath_segment/fbswath_fb_sigma',
#  '/freeboard_swath_segment/fbswath_fb_width',
#  '/freeboard_swath_segment/fbswath_lead_ndx_gt1l',
#  '/freeboard_swath_segment/fbswath_lead_ndx_gt1r',
#  '/freeboard_swath_segment/fbswath_lead_ndx_gt2l',
#  '/freeboard_swath_segment/fbswath_lead_ndx_gt2r',
#  '/freeboard_swath_segment/fbswath_lead_ndx_gt3l',
#  '/freeboard_swath_segment/fbswath_lead_ndx_gt3r',
#  '/freeboard_swath_segment/fbswath_lead_n_gt1l',
#  '/freeboard_swath_segment/fbswath_lead_n_gt1r',
#  '/freeboard_swath_segment/fbswath_lead_n_gt2l',
#  '/freeboard_swath_segment/fbswath_lead_n_gt2r',
#  '/freeboard_swath_segment/fbswath_lead_n_gt3l',
#  '/freeboard_swath_segment/fbswath_lead_n_gt3r',
#  '/freeboard_swath_segment/fbswath_refsurf_height',
#  '/freeboard_swath_segment/fbswath_refsurf_interp_flag',
#  '/freeboard_swath_segment/fbswath_refsurf_sigma',
#  '/freeboard_swath_segment/latitude',
#  '/freeboard_swath_segment/longitude',
#  '/freeboard_swath_segment/seg_dist_x',
#  '/freeboard_swath_segment/gt1l',
#  '/freeboard_swath_segment/gt1l/swath_freeboard',
#  '/freeboard_swath_segment/gt1l/swath_freeboard/delta_time',
#  '/freeboard_swath_segment/gt1l/swath_freeboard/fbswath_fb_confidence',
#  '/freeboard_swath_segment/gt1l/swath_freeboard/fbswath_fb_height',
#  '/freeboard_swath_segment/gt1l/swath_freeboard/fbswath_fb_quality_flag',
#  '/freeboard_swath_segment/gt1l/swath_freeboard/fbswath_fb_sigma',
#  '/freeboard_swath_segment/gt1l/swath_freeboard/fbswath_ndx',
#  '/freeboard_swath_segment/gt1l/swath_freeboard/height_segment_id',
#  '/freeboard_swath_segment/gt1l/swath_freeboard/latitude',
#  '/freeboard_swath_segment/gt1l/swath_freeboard/longitude',
#  '/freeboard_swath_segment/gt1r',
#  '/freeboard_swath_segment/gt1r/swath_freeboard',
#  '/freeboard_swath_segment/gt1r/swath_freeboard/delta_time',
#  '/freeboard_swath_segment/gt1r/swath_freeboard/fbswath_fb_confidence',
#  '/freeboard_swath_segment/gt1r/swath_freeboard/fbswath_fb_height',
#  '/freeboard_swath_segment/gt1r/swath_freeboard/fbswath_fb_quality_flag',
#  '/freeboard_swath_segment/gt1r/swath_freeboard/fbswath_fb_sigma',
#  '/freeboard_swath_segment/gt1r/swath_freeboard/fbswath_ndx',
#  '/freeboard_swath_segment/gt1r/swath_freeboard/height_segment_id',
#  '/freeboard_swath_segment/gt1r/swath_freeboard/latitude',
#  '/freeboard_swath_segment/gt1r/swath_freeboard/longitude',
#  '/freeboard_swath_segment/gt2l',
#  '/freeboard_swath_segment/gt2l/swath_freeboard',
#  '/freeboard_swath_segment/gt2l/swath_freeboard/delta_time',
#  '/freeboard_swath_segment/gt2l/swath_freeboard/fbswath_fb_confidence',
#  '/freeboard_swath_segment/gt2l/swath_freeboard/fbswath_fb_height',
#  '/freeboard_swath_segment/gt2l/swath_freeboard/fbswath_fb_quality_flag',
#  '/freeboard_swath_segment/gt2l/swath_freeboard/fbswath_fb_sigma',
#  '/freeboard_swath_segment/gt2l/swath_freeboard/fbswath_ndx',
#  '/freeboard_swath_segment/gt2l/swath_freeboard/height_segment_id',
#  '/freeboard_swath_segment/gt2l/swath_freeboard/latitude',
#  '/freeboard_swath_segment/gt2l/swath_freeboard/longitude',
#  '/freeboard_swath_segment/gt2r',
#  '/freeboard_swath_segment/gt2r/swath_freeboard',
#  '/freeboard_swath_segment/gt2r/swath_freeboard/delta_time',
#  '/freeboard_swath_segment/gt2r/swath_freeboard/fbswath_fb_confidence',
#  '/freeboard_swath_segment/gt2r/swath_freeboard/fbswath_fb_height',
#  '/freeboard_swath_segment/gt2r/swath_freeboard/fbswath_fb_quality_flag',
#  '/freeboard_swath_segment/gt2r/swath_freeboard/fbswath_fb_sigma',
#  '/freeboard_swath_segment/gt2r/swath_freeboard/fbswath_ndx',
#  '/freeboard_swath_segment/gt2r/swath_freeboard/height_segment_id',
#  '/freeboard_swath_segment/gt2r/swath_freeboard/latitude',
#  '/freeboard_swath_segment/gt2r/swath_freeboard/longitude',
#  '/freeboard_swath_segment/gt3l',
#  '/freeboard_swath_segment/gt3l/swath_freeboard',
#  '/freeboard_swath_segment/gt3l/swath_freeboard/delta_time',
#  '/freeboard_swath_segment/gt3l/swath_freeboard/fbswath_fb_confidence',
#  '/freeboard_swath_segment/gt3l/swath_freeboard/fbswath_fb_height',
#  '/freeboard_swath_segment/gt3l/swath_freeboard/fbswath_fb_quality_flag',
#  '/freeboard_swath_segment/gt3l/swath_freeboard/fbswath_fb_sigma',
#  '/freeboard_swath_segment/gt3l/swath_freeboard/fbswath_ndx',
#  '/freeboard_swath_segment/gt3l/swath_freeboard/height_segment_id',
#  '/freeboard_swath_segment/gt3l/swath_freeboard/latitude',
#  '/freeboard_swath_segment/gt3l/swath_freeboard/longitude',
#  '/freeboard_swath_segment/gt3r',
#  '/freeboard_swath_segment/gt3r/swath_freeboard',
#  '/freeboard_swath_segment/gt3r/swath_freeboard/delta_time',
#  '/freeboard_swath_segment/gt3r/swath_freeboard/fbswath_fb_confidence',
#  '/freeboard_swath_segment/gt3r/swath_freeboard/fbswath_fb_height',
#  '/freeboard_swath_segment/gt3r/swath_freeboard/fbswath_fb_quality_flag',
#  '/freeboard_swath_segment/gt3r/swath_freeboard/fbswath_fb_sigma',
#  '/freeboard_swath_segment/gt3r/swath_freeboard/fbswath_ndx',
#  '/freeboard_swath_segment/gt3r/swath_freeboard/height_segment_id',
#  '/freeboard_swath_segment/gt3r/swath_freeboard/latitude',
#  '/freeboard_swath_segment/gt3r/swath_freeboard/longitude',
#  '/gt1l',
#  '/gt1l/freeboard_beam_segment',
#  '/gt1l/freeboard_beam_segment/beam_fb_height',
#  '/gt1l/freeboard_beam_segment/beam_fb_hist',
#  '/gt1l/freeboard_beam_segment/beam_fb_length',
#  '/gt1l/freeboard_beam_segment/beam_fb_sigma',
#  '/gt1l/freeboard_beam_segment/beam_lead_n',
#  '/gt1l/freeboard_beam_segment/beam_lead_ndx',
#  '/gt1l/freeboard_beam_segment/beam_refsurf_alongtrack_slope',
#  '/gt1l/freeboard_beam_segment/beam_refsurf_height',
#  '/gt1l/freeboard_beam_segment/beam_refsurf_interp_flag',
#  '/gt1l/freeboard_beam_segment/beam_refsurf_sigma',
#  '/gt1l/freeboard_beam_segment/delta_time',
#  '/gt1l/freeboard_beam_segment/ds_si_hist_bins',
#  '/gt1l/freeboard_beam_segment/fbswath_ndx',
#  '/gt1l/freeboard_beam_segment/latitude',
#  '/gt1l/freeboard_beam_segment/longitude',
#  '/gt1l/freeboard_beam_segment/beam_freeboard',
#  '/gt1l/freeboard_beam_segment/beam_freeboard/beam_fb_confidence',
#  '/gt1l/freeboard_beam_segment/beam_freeboard/beam_fb_height',
#  '/gt1l/freeboard_beam_segment/beam_freeboard/beam_fb_quality_flag',
#  '/gt1l/freeboard_beam_segment/beam_freeboard/beam_fb_sigma',
#  '/gt1l/freeboard_beam_segment/beam_freeboard/beam_refsur_ndx',
#  '/gt1l/freeboard_beam_segment/beam_freeboard/delta_time',
#  '/gt1l/freeboard_beam_segment/beam_freeboard/geoseg_beg',
#  '/gt1l/freeboard_beam_segment/beam_freeboard/geoseg_end',
#  '/gt1l/freeboard_beam_segment/beam_freeboard/height_segment_id',
#  '/gt1l/freeboard_beam_segment/beam_freeboard/latitude',
#  '/gt1l/freeboard_beam_segment/beam_freeboard/longitude',
#  '/gt1l/freeboard_beam_segment/beam_freeboard/seg_dist_x',
#  '/gt1l/freeboard_beam_segment/geophysical',
#  '/gt1l/freeboard_beam_segment/geophysical/delta_time',
#  '/gt1l/freeboard_beam_segment/geophysical/height_segment_dac',
#  '/gt1l/freeboard_beam_segment/geophysical/height_segment_earth',
#  '/gt1l/freeboard_beam_segment/geophysical/height_segment_geoid',
#  '/gt1l/freeboard_beam_segment/geophysical/height_segment_load',
#  '/gt1l/freeboard_beam_segment/geophysical/height_segment_mss',
#  '/gt1l/freeboard_beam_segment/geophysical/height_segment_ocean',
#  '/gt1l/freeboard_beam_segment/geophysical/height_segment_tide_pole',
#  '/gt1l/freeboard_beam_segment/geophysical/latitude',
#  '/gt1l/freeboard_beam_segment/geophysical/longitude',
#  '/gt1l/freeboard_beam_segment/height_segments',
#  '/gt1l/freeboard_beam_segment/height_segments/asr_25',
#  '/gt1l/freeboard_beam_segment/height_segments/backgr_calc',
#  '/gt1l/freeboard_beam_segment/height_segments/background_r_norm',
#  '/gt1l/freeboard_beam_segment/height_segments/backgr_r_200',
#  '/gt1l/freeboard_beam_segment/height_segments/backgr_r_25',
#  '/gt1l/freeboard_beam_segment/height_segments/bsnow_con',
#  '/gt1l/freeboard_beam_segment/height_segments/bsnow_h',
#  '/gt1l/freeboard_beam_segment/height_segments/cloud_flag_asr',
#  '/gt1l/freeboard_beam_segment/height_segments/cloud_flag_atm',
#  '/gt1l/freeboard_beam_segment/height_segments/delta_time',
#  '/gt1l/freeboard_beam_segment/height_segments/height_segment_confidence',
#  '/gt1l/freeboard_beam_segment/height_segments/height_segment_height',
#  '/gt1l/freeboard_beam_segment/height_segments/height_segment_ib',
#  '/gt1l/freeboard_beam_segment/height_segments/height_segment_length_seg',
#  '/gt1l/freeboard_beam_segment/height_segments/height_segment_rms',
#  '/gt1l/freeboard_beam_segment/height_segments/height_segment_ssh_flag',
#  '/gt1l/freeboard_beam_segment/height_segments/height_segment_surf_sigma',
#  '/gt1l/freeboard_beam_segment/height_segments/height_segment_type',
#  '/gt1l/freeboard_beam_segment/height_segments/height_segment_w_gaussian',
#  '/gt1l/freeboard_beam_segment/height_segments/ice_conc',
#  '/gt1l/freeboard_beam_segment/height_segments/latitude',
#  '/gt1l/freeboard_beam_segment/height_segments/layer_flag',
#  '/gt1l/freeboard_beam_segment/height_segments/longitude',
#  '/gt1l/freeboard_beam_segment/height_segments/msw_flag',
#  '/gt1l/freeboard_beam_segment/height_segments/photon_rate',
#  '/gt1l/leads',
#  '/gt1l/leads/delta_time',
#  '/gt1l/leads/latitude',
#  '/gt1l/leads/lead_height',
#  '/gt1l/leads/lead_length',
#  '/gt1l/leads/lead_sigma',
#  '/gt1l/leads/longitude',
#  '/gt1l/leads/ssh_n',
#  '/gt1l/leads/ssh_ndx',
#  '/gt1r',
#  '/gt1r/freeboard_beam_segment',
#  '/gt1r/freeboard_beam_segment/beam_fb_height',
#  '/gt1r/freeboard_beam_segment/beam_fb_hist',
#  '/gt1r/freeboard_beam_segment/beam_fb_length',
#  '/gt1r/freeboard_beam_segment/beam_fb_sigma',
#  '/gt1r/freeboard_beam_segment/beam_lead_n',
#  '/gt1r/freeboard_beam_segment/beam_lead_ndx',
#  '/gt1r/freeboard_beam_segment/beam_refsurf_alongtrack_slope',
#  '/gt1r/freeboard_beam_segment/beam_refsurf_height',
#  '/gt1r/freeboard_beam_segment/beam_refsurf_interp_flag',
#  '/gt1r/freeboard_beam_segment/beam_refsurf_sigma',
#  '/gt1r/freeboard_beam_segment/delta_time',
#  '/gt1r/freeboard_beam_segment/ds_si_hist_bins',
#  '/gt1r/freeboard_beam_segment/fbswath_ndx',
#  '/gt1r/freeboard_beam_segment/latitude',
#  '/gt1r/freeboard_beam_segment/longitude',
#  '/gt1r/freeboard_beam_segment/beam_freeboard',
#  '/gt1r/freeboard_beam_segment/beam_freeboard/beam_fb_confidence',
#  '/gt1r/freeboard_beam_segment/beam_freeboard/beam_fb_height',
#  '/gt1r/freeboard_beam_segment/beam_freeboard/beam_fb_quality_flag',
#  '/gt1r/freeboard_beam_segment/beam_freeboard/beam_fb_sigma',
#  '/gt1r/freeboard_beam_segment/beam_freeboard/beam_refsur_ndx',
#  '/gt1r/freeboard_beam_segment/beam_freeboard/delta_time',
#  '/gt1r/freeboard_beam_segment/beam_freeboard/geoseg_beg',
#  '/gt1r/freeboard_beam_segment/beam_freeboard/geoseg_end',
#  '/gt1r/freeboard_beam_segment/beam_freeboard/height_segment_id',
#  '/gt1r/freeboard_beam_segment/beam_freeboard/latitude',
#  '/gt1r/freeboard_beam_segment/beam_freeboard/longitude',
#  '/gt1r/freeboard_beam_segment/beam_freeboard/seg_dist_x',
#  '/gt1r/freeboard_beam_segment/geophysical',
#  '/gt1r/freeboard_beam_segment/geophysical/delta_time',
#  '/gt1r/freeboard_beam_segment/geophysical/height_segment_dac',
#  '/gt1r/freeboard_beam_segment/geophysical/height_segment_earth',
#  '/gt1r/freeboard_beam_segment/geophysical/height_segment_geoid',
#  '/gt1r/freeboard_beam_segment/geophysical/height_segment_load',
#  '/gt1r/freeboard_beam_segment/geophysical/height_segment_mss',
#  '/gt1r/freeboard_beam_segment/geophysical/height_segment_ocean',
#  '/gt1r/freeboard_beam_segment/geophysical/height_segment_tide_pole',
#  '/gt1r/freeboard_beam_segment/geophysical/latitude',
#  '/gt1r/freeboard_beam_segment/geophysical/longitude',
#  '/gt1r/freeboard_beam_segment/height_segments',
#  '/gt1r/freeboard_beam_segment/height_segments/asr_25',
#  '/gt1r/freeboard_beam_segment/height_segments/backgr_calc',
#  '/gt1r/freeboard_beam_segment/height_segments/background_r_norm',
#  '/gt1r/freeboard_beam_segment/height_segments/backgr_r_200',
#  '/gt1r/freeboard_beam_segment/height_segments/backgr_r_25',
#  '/gt1r/freeboard_beam_segment/height_segments/bsnow_con',
#  '/gt1r/freeboard_beam_segment/height_segments/bsnow_h',
#  '/gt1r/freeboard_beam_segment/height_segments/cloud_flag_asr',
#  '/gt1r/freeboard_beam_segment/height_segments/cloud_flag_atm',
#  '/gt1r/freeboard_beam_segment/height_segments/delta_time',
#  '/gt1r/freeboard_beam_segment/height_segments/height_segment_confidence',
#  '/gt1r/freeboard_beam_segment/height_segments/height_segment_height',
#  '/gt1r/freeboard_beam_segment/height_segments/height_segment_ib',
#  '/gt1r/freeboard_beam_segment/height_segments/height_segment_length_seg',
#  '/gt1r/freeboard_beam_segment/height_segments/height_segment_rms',
#  '/gt1r/freeboard_beam_segment/height_segments/height_segment_ssh_flag',
#  '/gt1r/freeboard_beam_segment/height_segments/height_segment_surf_sigma',
#  '/gt1r/freeboard_beam_segment/height_segments/height_segment_type',
#  '/gt1r/freeboard_beam_segment/height_segments/height_segment_w_gaussian',
#  '/gt1r/freeboard_beam_segment/height_segments/ice_conc',
#  '/gt1r/freeboard_beam_segment/height_segments/latitude',
#  '/gt1r/freeboard_beam_segment/height_segments/layer_flag',
#  '/gt1r/freeboard_beam_segment/height_segments/longitude',
#  '/gt1r/freeboard_beam_segment/height_segments/msw_flag',
#  '/gt1r/freeboard_beam_segment/height_segments/photon_rate',
#  '/gt1r/leads',
#  '/gt1r/leads/delta_time',
#  '/gt1r/leads/latitude',
#  '/gt1r/leads/lead_height',
#  '/gt1r/leads/lead_length',
#  '/gt1r/leads/lead_sigma',
#  '/gt1r/leads/longitude',
#  '/gt1r/leads/ssh_n',
#  '/gt1r/leads/ssh_ndx',
#  '/gt2l',
#  '/gt2l/freeboard_beam_segment',
#  '/gt2l/freeboard_beam_segment/beam_fb_height',
#  '/gt2l/freeboard_beam_segment/beam_fb_hist',
#  '/gt2l/freeboard_beam_segment/beam_fb_length',
#  '/gt2l/freeboard_beam_segment/beam_fb_sigma',
#  '/gt2l/freeboard_beam_segment/beam_lead_n',
#  '/gt2l/freeboard_beam_segment/beam_lead_ndx',
#  '/gt2l/freeboard_beam_segment/beam_refsurf_alongtrack_slope',
#  '/gt2l/freeboard_beam_segment/beam_refsurf_height',
#  '/gt2l/freeboard_beam_segment/beam_refsurf_interp_flag',
#  '/gt2l/freeboard_beam_segment/beam_refsurf_sigma',
#  '/gt2l/freeboard_beam_segment/delta_time',
#  '/gt2l/freeboard_beam_segment/ds_si_hist_bins',
#  '/gt2l/freeboard_beam_segment/fbswath_ndx',
#  '/gt2l/freeboard_beam_segment/latitude',
#  '/gt2l/freeboard_beam_segment/longitude',
#  '/gt2l/freeboard_beam_segment/beam_freeboard',
#  '/gt2l/freeboard_beam_segment/beam_freeboard/beam_fb_confidence',
#  '/gt2l/freeboard_beam_segment/beam_freeboard/beam_fb_height',
#  '/gt2l/freeboard_beam_segment/beam_freeboard/beam_fb_quality_flag',
#  '/gt2l/freeboard_beam_segment/beam_freeboard/beam_fb_sigma',
#  '/gt2l/freeboard_beam_segment/beam_freeboard/beam_refsur_ndx',
#  '/gt2l/freeboard_beam_segment/beam_freeboard/delta_time',
#  '/gt2l/freeboard_beam_segment/beam_freeboard/geoseg_beg',
#  '/gt2l/freeboard_beam_segment/beam_freeboard/geoseg_end',
#  '/gt2l/freeboard_beam_segment/beam_freeboard/height_segment_id',
#  '/gt2l/freeboard_beam_segment/beam_freeboard/latitude',
#  '/gt2l/freeboard_beam_segment/beam_freeboard/longitude',
#  '/gt2l/freeboard_beam_segment/beam_freeboard/seg_dist_x',
#  '/gt2l/freeboard_beam_segment/geophysical',
#  '/gt2l/freeboard_beam_segment/geophysical/delta_time',
#  '/gt2l/freeboard_beam_segment/geophysical/height_segment_dac',
#  '/gt2l/freeboard_beam_segment/geophysical/height_segment_earth',
#  '/gt2l/freeboard_beam_segment/geophysical/height_segment_geoid',
#  '/gt2l/freeboard_beam_segment/geophysical/height_segment_load',
#  '/gt2l/freeboard_beam_segment/geophysical/height_segment_mss',
#  '/gt2l/freeboard_beam_segment/geophysical/height_segment_ocean',
#  '/gt2l/freeboard_beam_segment/geophysical/height_segment_tide_pole',
#  '/gt2l/freeboard_beam_segment/geophysical/latitude',
#  '/gt2l/freeboard_beam_segment/geophysical/longitude',
#  '/gt2l/freeboard_beam_segment/height_segments',
#  '/gt2l/freeboard_beam_segment/height_segments/asr_25',
#  '/gt2l/freeboard_beam_segment/height_segments/backgr_calc',
#  '/gt2l/freeboard_beam_segment/height_segments/background_r_norm',
#  '/gt2l/freeboard_beam_segment/height_segments/backgr_r_200',
#  '/gt2l/freeboard_beam_segment/height_segments/backgr_r_25',
#  '/gt2l/freeboard_beam_segment/height_segments/bsnow_con',
#  '/gt2l/freeboard_beam_segment/height_segments/bsnow_h',
#  '/gt2l/freeboard_beam_segment/height_segments/cloud_flag_asr',
#  '/gt2l/freeboard_beam_segment/height_segments/cloud_flag_atm',
#  '/gt2l/freeboard_beam_segment/height_segments/delta_time',
#  '/gt2l/freeboard_beam_segment/height_segments/height_segment_confidence',
#  '/gt2l/freeboard_beam_segment/height_segments/height_segment_height',
#  '/gt2l/freeboard_beam_segment/height_segments/height_segment_ib',
#  '/gt2l/freeboard_beam_segment/height_segments/height_segment_length_seg',
#  '/gt2l/freeboard_beam_segment/height_segments/height_segment_rms',
#  '/gt2l/freeboard_beam_segment/height_segments/height_segment_ssh_flag',
#  '/gt2l/freeboard_beam_segment/height_segments/height_segment_surf_sigma',
#  '/gt2l/freeboard_beam_segment/height_segments/height_segment_type',
#  '/gt2l/freeboard_beam_segment/height_segments/height_segment_w_gaussian',
#  '/gt2l/freeboard_beam_segment/height_segments/ice_conc',
#  '/gt2l/freeboard_beam_segment/height_segments/latitude',
#  '/gt2l/freeboard_beam_segment/height_segments/layer_flag',
#  '/gt2l/freeboard_beam_segment/height_segments/longitude',
#  '/gt2l/freeboard_beam_segment/height_segments/msw_flag',
#  '/gt2l/freeboard_beam_segment/height_segments/photon_rate',
#  '/gt2l/leads',
#  '/gt2l/leads/delta_time',
#  '/gt2l/leads/latitude',
#  '/gt2l/leads/lead_height',
#  '/gt2l/leads/lead_length',
#  '/gt2l/leads/lead_sigma',
#  '/gt2l/leads/longitude',
#  '/gt2l/leads/ssh_n',
#  '/gt2l/leads/ssh_ndx',
#  '/gt2r',
#  '/gt2r/freeboard_beam_segment',
#  '/gt2r/freeboard_beam_segment/beam_fb_height',
#  '/gt2r/freeboard_beam_segment/beam_fb_hist',
#  '/gt2r/freeboard_beam_segment/beam_fb_length',
#  '/gt2r/freeboard_beam_segment/beam_fb_sigma',
#  '/gt2r/freeboard_beam_segment/beam_lead_n',
#  '/gt2r/freeboard_beam_segment/beam_lead_ndx',
#  '/gt2r/freeboard_beam_segment/beam_refsurf_alongtrack_slope',
#  '/gt2r/freeboard_beam_segment/beam_refsurf_height',
#  '/gt2r/freeboard_beam_segment/beam_refsurf_interp_flag',
#  '/gt2r/freeboard_beam_segment/beam_refsurf_sigma',
#  '/gt2r/freeboard_beam_segment/delta_time',
#  '/gt2r/freeboard_beam_segment/ds_si_hist_bins',
#  '/gt2r/freeboard_beam_segment/fbswath_ndx',
#  '/gt2r/freeboard_beam_segment/latitude',
#  '/gt2r/freeboard_beam_segment/longitude',
#  '/gt2r/freeboard_beam_segment/beam_freeboard',
#  '/gt2r/freeboard_beam_segment/beam_freeboard/beam_fb_confidence',
#  '/gt2r/freeboard_beam_segment/beam_freeboard/beam_fb_height',
#  '/gt2r/freeboard_beam_segment/beam_freeboard/beam_fb_quality_flag',
#  '/gt2r/freeboard_beam_segment/beam_freeboard/beam_fb_sigma',
#  '/gt2r/freeboard_beam_segment/beam_freeboard/beam_refsur_ndx',
#  '/gt2r/freeboard_beam_segment/beam_freeboard/delta_time',
#  '/gt2r/freeboard_beam_segment/beam_freeboard/geoseg_beg',
#  '/gt2r/freeboard_beam_segment/beam_freeboard/geoseg_end',
#  '/gt2r/freeboard_beam_segment/beam_freeboard/height_segment_id',
#  '/gt2r/freeboard_beam_segment/beam_freeboard/latitude',
#  '/gt2r/freeboard_beam_segment/beam_freeboard/longitude',
#  '/gt2r/freeboard_beam_segment/beam_freeboard/seg_dist_x',
#  '/gt2r/freeboard_beam_segment/geophysical',
#  '/gt2r/freeboard_beam_segment/geophysical/delta_time',
#  '/gt2r/freeboard_beam_segment/geophysical/height_segment_dac',
#  '/gt2r/freeboard_beam_segment/geophysical/height_segment_earth',
#  '/gt2r/freeboard_beam_segment/geophysical/height_segment_geoid',
#  '/gt2r/freeboard_beam_segment/geophysical/height_segment_load',
#  '/gt2r/freeboard_beam_segment/geophysical/height_segment_mss',
#  '/gt2r/freeboard_beam_segment/geophysical/height_segment_ocean',
#  '/gt2r/freeboard_beam_segment/geophysical/height_segment_tide_pole',
#  '/gt2r/freeboard_beam_segment/geophysical/latitude',
#  '/gt2r/freeboard_beam_segment/geophysical/longitude',
#  '/gt2r/freeboard_beam_segment/height_segments',
#  '/gt2r/freeboard_beam_segment/height_segments/asr_25',
#  '/gt2r/freeboard_beam_segment/height_segments/backgr_calc',
#  '/gt2r/freeboard_beam_segment/height_segments/background_r_norm',
#  '/gt2r/freeboard_beam_segment/height_segments/backgr_r_200',
#  '/gt2r/freeboard_beam_segment/height_segments/backgr_r_25',
#  '/gt2r/freeboard_beam_segment/height_segments/bsnow_con',
#  '/gt2r/freeboard_beam_segment/height_segments/bsnow_h',
#  '/gt2r/freeboard_beam_segment/height_segments/cloud_flag_asr',
#  '/gt2r/freeboard_beam_segment/height_segments/cloud_flag_atm',
#  '/gt2r/freeboard_beam_segment/height_segments/delta_time',
#  '/gt2r/freeboard_beam_segment/height_segments/height_segment_confidence',
#  '/gt2r/freeboard_beam_segment/height_segments/height_segment_height',
#  '/gt2r/freeboard_beam_segment/height_segments/height_segment_ib',
#  '/gt2r/freeboard_beam_segment/height_segments/height_segment_length_seg',
#  '/gt2r/freeboard_beam_segment/height_segments/height_segment_rms',
#  '/gt2r/freeboard_beam_segment/height_segments/height_segment_ssh_flag',
#  '/gt2r/freeboard_beam_segment/height_segments/height_segment_surf_sigma',
#  '/gt2r/freeboard_beam_segment/height_segments/height_segment_type',
#  '/gt2r/freeboard_beam_segment/height_segments/height_segment_w_gaussian',
#  '/gt2r/freeboard_beam_segment/height_segments/ice_conc',
#  '/gt2r/freeboard_beam_segment/height_segments/latitude',
#  '/gt2r/freeboard_beam_segment/height_segments/layer_flag',
#  '/gt2r/freeboard_beam_segment/height_segments/longitude',
#  '/gt2r/freeboard_beam_segment/height_segments/msw_flag',
#  '/gt2r/freeboard_beam_segment/height_segments/photon_rate',
#  '/gt2r/leads',
#  '/gt2r/leads/delta_time',
#  '/gt2r/leads/latitude',
#  '/gt2r/leads/lead_height',
#  '/gt2r/leads/lead_length',
#  '/gt2r/leads/lead_sigma',
#  '/gt2r/leads/longitude',
#  '/gt2r/leads/ssh_n',
#  '/gt2r/leads/ssh_ndx',
#  '/gt3l',
#  '/gt3l/freeboard_beam_segment',
#  '/gt3l/freeboard_beam_segment/beam_fb_height',
#  '/gt3l/freeboard_beam_segment/beam_fb_hist',
#  '/gt3l/freeboard_beam_segment/beam_fb_length',
#  '/gt3l/freeboard_beam_segment/beam_fb_sigma',
#  '/gt3l/freeboard_beam_segment/beam_lead_n',
#  '/gt3l/freeboard_beam_segment/beam_lead_ndx',
#  '/gt3l/freeboard_beam_segment/beam_refsurf_alongtrack_slope',
#  '/gt3l/freeboard_beam_segment/beam_refsurf_height',
#  '/gt3l/freeboard_beam_segment/beam_refsurf_interp_flag',
#  '/gt3l/freeboard_beam_segment/beam_refsurf_sigma',
#  '/gt3l/freeboard_beam_segment/delta_time',
#  '/gt3l/freeboard_beam_segment/ds_si_hist_bins',
#  '/gt3l/freeboard_beam_segment/fbswath_ndx',
#  '/gt3l/freeboard_beam_segment/latitude',
#  '/gt3l/freeboard_beam_segment/longitude',
#  '/gt3l/freeboard_beam_segment/beam_freeboard',
#  '/gt3l/freeboard_beam_segment/beam_freeboard/beam_fb_confidence',
#  '/gt3l/freeboard_beam_segment/beam_freeboard/beam_fb_height',
#  '/gt3l/freeboard_beam_segment/beam_freeboard/beam_fb_quality_flag',
#  '/gt3l/freeboard_beam_segment/beam_freeboard/beam_fb_sigma',
#  '/gt3l/freeboard_beam_segment/beam_freeboard/beam_refsur_ndx',
#  '/gt3l/freeboard_beam_segment/beam_freeboard/delta_time',
#  '/gt3l/freeboard_beam_segment/beam_freeboard/geoseg_beg',
#  '/gt3l/freeboard_beam_segment/beam_freeboard/geoseg_end',
#  '/gt3l/freeboard_beam_segment/beam_freeboard/height_segment_id',
#  '/gt3l/freeboard_beam_segment/beam_freeboard/latitude',
#  '/gt3l/freeboard_beam_segment/beam_freeboard/longitude',
#  '/gt3l/freeboard_beam_segment/beam_freeboard/seg_dist_x',
#  '/gt3l/freeboard_beam_segment/geophysical',
#  '/gt3l/freeboard_beam_segment/geophysical/delta_time',
#  '/gt3l/freeboard_beam_segment/geophysical/height_segment_dac',
#  '/gt3l/freeboard_beam_segment/geophysical/height_segment_earth',
#  '/gt3l/freeboard_beam_segment/geophysical/height_segment_geoid',
#  '/gt3l/freeboard_beam_segment/geophysical/height_segment_load',
#  '/gt3l/freeboard_beam_segment/geophysical/height_segment_mss',
#  '/gt3l/freeboard_beam_segment/geophysical/height_segment_ocean',
#  '/gt3l/freeboard_beam_segment/geophysical/height_segment_tide_pole',
#  '/gt3l/freeboard_beam_segment/geophysical/latitude',
#  '/gt3l/freeboard_beam_segment/geophysical/longitude',
#  '/gt3l/freeboard_beam_segment/height_segments',
#  '/gt3l/freeboard_beam_segment/height_segments/asr_25',
#  '/gt3l/freeboard_beam_segment/height_segments/backgr_calc',
#  '/gt3l/freeboard_beam_segment/height_segments/background_r_norm',
#  '/gt3l/freeboard_beam_segment/height_segments/backgr_r_200',
#  '/gt3l/freeboard_beam_segment/height_segments/backgr_r_25',
#  '/gt3l/freeboard_beam_segment/height_segments/bsnow_con',
#  '/gt3l/freeboard_beam_segment/height_segments/bsnow_h',
#  '/gt3l/freeboard_beam_segment/height_segments/cloud_flag_asr',
#  '/gt3l/freeboard_beam_segment/height_segments/cloud_flag_atm',
#  '/gt3l/freeboard_beam_segment/height_segments/delta_time',
#  '/gt3l/freeboard_beam_segment/height_segments/height_segment_confidence',
#  '/gt3l/freeboard_beam_segment/height_segments/height_segment_height',
#  '/gt3l/freeboard_beam_segment/height_segments/height_segment_ib',
#  '/gt3l/freeboard_beam_segment/height_segments/height_segment_length_seg',
#  '/gt3l/freeboard_beam_segment/height_segments/height_segment_rms',
#  '/gt3l/freeboard_beam_segment/height_segments/height_segment_ssh_flag',
#  '/gt3l/freeboard_beam_segment/height_segments/height_segment_surf_sigma',
#  '/gt3l/freeboard_beam_segment/height_segments/height_segment_type',
#  '/gt3l/freeboard_beam_segment/height_segments/height_segment_w_gaussian',
#  '/gt3l/freeboard_beam_segment/height_segments/ice_conc',
#  '/gt3l/freeboard_beam_segment/height_segments/latitude',
#  '/gt3l/freeboard_beam_segment/height_segments/layer_flag',
#  '/gt3l/freeboard_beam_segment/height_segments/longitude',
#  '/gt3l/freeboard_beam_segment/height_segments/msw_flag',
#  '/gt3l/freeboard_beam_segment/height_segments/photon_rate',
#  '/gt3l/leads',
#  '/gt3l/leads/delta_time',
#  '/gt3l/leads/latitude',
#  '/gt3l/leads/lead_height',
#  '/gt3l/leads/lead_length',
#  '/gt3l/leads/lead_sigma',
#  '/gt3l/leads/longitude',
#  '/gt3l/leads/ssh_n',
#  '/gt3l/leads/ssh_ndx',
#  '/gt3r',
#  '/gt3r/freeboard_beam_segment',
#  '/gt3r/freeboard_beam_segment/beam_fb_height',
#  '/gt3r/freeboard_beam_segment/beam_fb_hist',
#  '/gt3r/freeboard_beam_segment/beam_fb_length',
#  '/gt3r/freeboard_beam_segment/beam_fb_sigma',
#  '/gt3r/freeboard_beam_segment/beam_lead_n',
#  '/gt3r/freeboard_beam_segment/beam_lead_ndx',
#  '/gt3r/freeboard_beam_segment/beam_refsurf_alongtrack_slope',
#  '/gt3r/freeboard_beam_segment/beam_refsurf_height',
#  '/gt3r/freeboard_beam_segment/beam_refsurf_interp_flag',
#  '/gt3r/freeboard_beam_segment/beam_refsurf_sigma',
#  '/gt3r/freeboard_beam_segment/delta_time',
#  '/gt3r/freeboard_beam_segment/ds_si_hist_bins',
#  '/gt3r/freeboard_beam_segment/fbswath_ndx',
#  '/gt3r/freeboard_beam_segment/latitude',
#  '/gt3r/freeboard_beam_segment/longitude',
#  '/gt3r/freeboard_beam_segment/beam_freeboard',
#  '/gt3r/freeboard_beam_segment/beam_freeboard/beam_fb_confidence',
#  '/gt3r/freeboard_beam_segment/beam_freeboard/beam_fb_height',
#  '/gt3r/freeboard_beam_segment/beam_freeboard/beam_fb_quality_flag',
#  '/gt3r/freeboard_beam_segment/beam_freeboard/beam_fb_sigma',
#  '/gt3r/freeboard_beam_segment/beam_freeboard/beam_refsur_ndx',
#  '/gt3r/freeboard_beam_segment/beam_freeboard/delta_time',
#  '/gt3r/freeboard_beam_segment/beam_freeboard/geoseg_beg',
#  '/gt3r/freeboard_beam_segment/beam_freeboard/geoseg_end',
#  '/gt3r/freeboard_beam_segment/beam_freeboard/height_segment_id',
#  '/gt3r/freeboard_beam_segment/beam_freeboard/latitude',
#  '/gt3r/freeboard_beam_segment/beam_freeboard/longitude',
#  '/gt3r/freeboard_beam_segment/beam_freeboard/seg_dist_x',
#  '/gt3r/freeboard_beam_segment/geophysical',
#  '/gt3r/freeboard_beam_segment/geophysical/delta_time',
#  '/gt3r/freeboard_beam_segment/geophysical/height_segment_dac',
#  '/gt3r/freeboard_beam_segment/geophysical/height_segment_earth',
#  '/gt3r/freeboard_beam_segment/geophysical/height_segment_geoid',
#  '/gt3r/freeboard_beam_segment/geophysical/height_segment_load',
#  '/gt3r/freeboard_beam_segment/geophysical/height_segment_mss',
#  '/gt3r/freeboard_beam_segment/geophysical/height_segment_ocean',
#  '/gt3r/freeboard_beam_segment/geophysical/height_segment_tide_pole',
#  '/gt3r/freeboard_beam_segment/geophysical/latitude',
#  '/gt3r/freeboard_beam_segment/geophysical/longitude',
#  '/gt3r/freeboard_beam_segment/height_segments',
#  '/gt3r/freeboard_beam_segment/height_segments/asr_25',
#  '/gt3r/freeboard_beam_segment/height_segments/backgr_calc',
#  '/gt3r/freeboard_beam_segment/height_segments/background_r_norm',
#  '/gt3r/freeboard_beam_segment/height_segments/backgr_r_200',
#  '/gt3r/freeboard_beam_segment/height_segments/backgr_r_25',
#  '/gt3r/freeboard_beam_segment/height_segments/bsnow_con',
#  '/gt3r/freeboard_beam_segment/height_segments/bsnow_h',
#  '/gt3r/freeboard_beam_segment/height_segments/cloud_flag_asr',
#  '/gt3r/freeboard_beam_segment/height_segments/cloud_flag_atm',
#  '/gt3r/freeboard_beam_segment/height_segments/delta_time',
#  '/gt3r/freeboard_beam_segment/height_segments/height_segment_confidence',
#  '/gt3r/freeboard_beam_segment/height_segments/height_segment_height',
#  '/gt3r/freeboard_beam_segment/height_segments/height_segment_ib',
#  '/gt3r/freeboard_beam_segment/height_segments/height_segment_length_seg',
#  '/gt3r/freeboard_beam_segment/height_segments/height_segment_rms',
#  '/gt3r/freeboard_beam_segment/height_segments/height_segment_ssh_flag',
#  '/gt3r/freeboard_beam_segment/height_segments/height_segment_surf_sigma',
#  '/gt3r/freeboard_beam_segment/height_segments/height_segment_type',
#  '/gt3r/freeboard_beam_segment/height_segments/height_segment_w_gaussian',
#  '/gt3r/freeboard_beam_segment/height_segments/ice_conc',
#  '/gt3r/freeboard_beam_segment/height_segments/latitude',
#  '/gt3r/freeboard_beam_segment/height_segments/layer_flag',
#  '/gt3r/freeboard_beam_segment/height_segments/longitude',
#  '/gt3r/freeboard_beam_segment/height_segments/msw_flag',
#  '/gt3r/freeboard_beam_segment/height_segments/photon_rate',
#  '/gt3r/leads',
#  '/gt3r/leads/delta_time',
#  '/gt3r/leads/latitude',
#  '/gt3r/leads/lead_height',
#  '/gt3r/leads/lead_length',
#  '/gt3r/leads/lead_sigma',
#  '/gt3r/leads/longitude',
#  '/gt3r/leads/ssh_n',
#  '/gt3r/leads/ssh_ndx',
#  '/orbit_info',
#  '/orbit_info/crossing_time',
#  '/orbit_info/cycle_number',
#  '/orbit_info/lan',
#  '/orbit_info/orbit_number',
#  '/orbit_info/rgt',
#  '/orbit_info/sc_orient',
#  '/orbit_info/sc_orient_time',
#  '/quality_assessment',
#  '/quality_assessment/qa_granule_fail_reason',
#  '/quality_assessment/qa_granule_pass_fail']

# %% [markdown]
# #### Next, let's explore the reformatting options available.

# %% [markdown]
# We can view the entire list of variables if desired:

# %%
#Set NSIDC data access base URL
base_url = 'https://n5eil02u.ecs.nsidc.org/egi/request'

# %%
# Set number of granules requested per order, which we will initially set to 10.
page_size = 20

#Determine number of pages basd on page_size and total granules. Loop requests by this value
page_num = math.ceil(len(granules)/page_size)

#Set request mode. 
request_mode = 'async'

# Determine how many individual orders we will request based on the number of granules requested
print(page_num)
# Out:
# 2

# %% [markdown]
# #### After all of these KVP inputs, what does our request look like? Here's a summary of all possible KVPs that we explored, both for CMR searching and for the subsetter:
#
# #### CMR search keys:
# * `short_name=`
# * `version=`
# * `temporal=`
# * `bounding_box=`
# * `polygon=`
#
# #### Customization service keys:
# * `time=`
# * `bbox=`
# * `bounding_shape=`
# * `format=`
# * `projection=`
# * `projection_parameters=`
# * `Coverage=`
#
# #### No customization (access only):
# * `agent=`
# * `include_meta=`
#     * `Y` by default. `N` for No metadata requested.
#
# #### Request configuration keys:
# * `request_mode=`
# * `page_size=`
# * `page_num=`
# * `token=`
# * `email=`

# %% [markdown]
# #### If we were to create an API request based on our request parameters and submit into a web browser for example, here's what we end up with:

# %%
print(bbox)
subset_params = {
    'short_name': short_name, 
#    'version': latest_version, 
    'temporal': temporal, 
#    'time': timevar, 
    'bounding_box': bbox, 
#    'Coverage': coverage, 
    'request_mode': request_mode, 
    'page_size': page_size,  
    'token': token, 
    'email': email, 
    'agent': 'NO',
    }
print(subset_params)
# Out:
# -180,60,-160,85
# {'short_name': 'ATL10', 'temporal': '2018-12-01T00:00:00Z,2018-12-06T23:59:59Z', 'bounding_box': '-180,60,-160,85', 'request_mode': 'async', 'page_size': 20, 'token': 'E62B4B88-9593-546B-D952-510D17894DA3', 'email': 'schweig@uw.edu', 'agent': 'NO'}

# %% [markdown]
# #### We'll request the same data but without any subsetting services applied. Let's create another request parameter dictionary with the `time` and `coverage` service keys removed, and we'll add `agent=NO` instead.

# %% [markdown]
# ## Request Data
#
# #### Finally, we'll download the data directly to this notebook directory in a new Outputs folder. The progress of each order will be reported.
#
# We'll start by creating an output folder if the folder does not already exist.

# %%
path = '/home/jovyan/DATA/ATL10'
if not os.path.exists(path):
    os.mkdir(path)
print(page_num)
# Out:
# 2

# %% [markdown]
# First we'll submit our request without subsetting services:

# %%
# Request data service for each page number, and unzip outputs

for i in range(page_num):
    page_val = i + 1
    print('Order: ', page_val)
    subset_params.update( {'page_num': page_val} )
    
# Post polygon to API endpoint for polygon subsetting to subset based on original, non-simplified KML file

#    shape_post = {'shapefile': open(kml_filepath, 'rb')}
#    request = session.post(base_url, params=subset_params, files=shape_post) 
    
# FOR ALL OTHER REQUESTS THAT DO NOT UTILIZED AN UPLOADED POLYGON FILE, USE A GET REQUEST INSTEAD OF POST:
    request = session.get(base_url, params=subset_params)
    
    print('Request HTTP response: ', request.status_code)

# Raise bad request: Loop will stop for bad response code.
    request.raise_for_status()
    print('Order request URL: ', request.url)
    esir_root = ET.fromstring(request.content)
    print("esir_root",esir_root)
    print('Order request response XML content: ', request.content)

# Look up order ID
    orderlist = []
    print("Order Look Now:")
    for order in esir_root.findall("./order/"):
        print('Order.Text:',order.text)
        orderlist.append(order.text)
        print(orderlist)
    orderID = orderlist[0]
    print('order ID: ', orderID)

# Create status URL
    statusURL = base_url + '/' + orderID
    print('status URL: ', statusURL)

# Find order status
    request_response = session.get(statusURL)    
    print('HTTP response from order response URL: ', request_response.status_code)
    
# Raise bad request: Loop will stop for bad response code.
    request_response.raise_for_status()
    request_root = ET.fromstring(request_response.content)
    statuslist = []
    for status in request_root.findall("./requestStatus/"):
        statuslist.append(status.text)
    status = statuslist[0]
    print('Data request ', page_val, ' is submitting...')
    print('Initial request status is ', status)

# Continue to loop while request is still processing
    while status == 'pending' or status == 'processing': 
        print('Status is not complete. Trying again.')
        time.sleep(10)
        loop_response = session.get(statusURL)

# Raise bad request: Loop will stop for bad response code.
        loop_response.raise_for_status()
        loop_root = ET.fromstring(loop_response.content)

# Find status
        statuslist = []
        for status in loop_root.findall("./requestStatus/"):
            statuslist.append(status.text)
        status = statuslist[0]
        print('Retry request status is: ', status)
        if status == 'pending' or status == 'processing':
            continue

# Order can either complete, complete_with_errors, or fail:
# Provide complete_with_errors error message:
    if status == 'complete_with_errors' or status == 'failed':
        messagelist = []
        for message in loop_root.findall("./processInfo/"):
            messagelist.append(message.text)
        print('error messages:')
        pprint.pprint(messagelist)

# Download zipped order if status is complete or complete_with_errors
    if status == 'complete' or status == 'complete_with_errors':
        downloadURL = 'https://n5eil02u.ecs.nsidc.org/esir/' + orderID + '.zip'
        print('Zip download URL: ', downloadURL)
        print('Beginning download of zipped output...')
        zip_response = session.get(downloadURL)
        # Raise bad request: Loop will stop for bad response code.
        zip_response.raise_for_status()
        with zipfile.ZipFile(io.BytesIO(zip_response.content)) as z:
            z.extractall(path)
        print('Data request', page_val, 'is complete.')
    else: print('Request failed.')
# Out:
# Order:  1
# Request HTTP response:  201
# Order request URL:  https://n5eil02u.ecs.nsidc.org/egi/request?short_name=ATL10&temporal=2018-12-01T00%3A00%3A00Z%2C2018-12-06T23%3A59%3A59Z&bounding_box=-180%2C60%2C-160%2C85&request_mode=async&page_size=20&token=E62B4B88-9593-546B-D952-510D17894DA3&email=schweig%40uw.edu&agent=NO&page_num=1
# esir_root <Element '{http://eosdis.nasa.gov/esi/rsp/e}agentResponse' at 0x7f86c3e99408>
# Order request response XML content:  b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?>\n<eesi:agentResponse xsi:schemaLocation="http://eosdis.nasa.gov/esi/rsp/e https://newsroom.gsfc.nasa.gov/esi/8.1/schemas/ESIAgentResponseExternal.xsd" xmlns="" xmlns:iesi="http://eosdis.nasa.gov/esi/rsp/i" xmlns:ssw="http://newsroom.gsfc.nasa.gov/esi/rsp/ssw" xmlns:eesi="http://eosdis.nasa.gov/esi/rsp/e" xmlns:esi="http://eosdis.nasa.gov/esi/rsp" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">\n    <order>\n        <orderId>5000000320068</orderId>\n        <Instructions>You may receive an email about your order if you specified an EMAIL address. &lt;br/&gt;&lt;br/&gt;The instructions used to process this order are:  Processing tool=NO. Granule id(s)=SC:ATL10.209:160722641,SC:ATL10.001:161206731,SC:ATL10.001:161223929,SC:ATL10.001:161226011,SC:ATL10.001:161223827,SC:ATL10.001:161224302,SC:ATL10.001:161225911,SC:ATL10.001:161225900,SC:ATL10.001:161204159,SC:ATL10.001:161225948,SC:ATL10.001:161204128,SC:ATL10.001:161225897,SC:ATL10.001:161225935,SC:ATL10.001:161225652,SC:ATL10.001:161226440,SC:ATL10.001:161225968,SC:ATL10.001:161226437,SC:ATL10.001:161175247,SC:ATL10.001:161183469,SC:ATL10.001:161196374. Email address=schweig@uw.edu.</Instructions>\n    </order>\n    <contactInformation>\n        <contactName>NSIDC User Services</contactName>\n        <contactEmail>nsidc@nsidc.org</contactEmail>\n    </contactInformation>\n    <processInfo>\n        <processDuration>PT0.123S</processDuration>\n        <subagentId>NO</subagentId>\n    </processInfo>\n    <requestStatus>\n        <status>processing</status>\n        <numberProcessed>0</numberProcessed>\n        <totalNumber>20</totalNumber>\n    </requestStatus>\n</eesi:agentResponse>\n'
# Order Look Now:
# Order.Text: 5000000320068
# ['5000000320068']
# Order.Text: You may receive an email about your order if you specified an EMAIL address. <br/><br/>The instructions used to process this order are:  Processing tool=NO. Granule id(s)=SC:ATL10.209:160722641,SC:ATL10.001:161206731,SC:ATL10.001:161223929,SC:ATL10.001:161226011,SC:ATL10.001:161223827,SC:ATL10.001:161224302,SC:ATL10.001:161225911,SC:ATL10.001:161225900,SC:ATL10.001:161204159,SC:ATL10.001:161225948,SC:ATL10.001:161204128,SC:ATL10.001:161225897,SC:ATL10.001:161225935,SC:ATL10.001:161225652,SC:ATL10.001:161226440,SC:ATL10.001:161225968,SC:ATL10.001:161226437,SC:ATL10.001:161175247,SC:ATL10.001:161183469,SC:ATL10.001:161196374. Email address=schweig@uw.edu.
# ['5000000320068', 'You may receive an email about your order if you specified an EMAIL address. <br/><br/>The instructions used to process this order are:  Processing tool=NO. Granule id(s)=SC:ATL10.209:160722641,SC:ATL10.001:161206731,SC:ATL10.001:161223929,SC:ATL10.001:161226011,SC:ATL10.001:161223827,SC:ATL10.001:161224302,SC:ATL10.001:161225911,SC:ATL10.001:161225900,SC:ATL10.001:161204159,SC:ATL10.001:161225948,SC:ATL10.001:161204128,SC:ATL10.001:161225897,SC:ATL10.001:161225935,SC:ATL10.001:161225652,SC:ATL10.001:161226440,SC:ATL10.001:161225968,SC:ATL10.001:161226437,SC:ATL10.001:161175247,SC:ATL10.001:161183469,SC:ATL10.001:161196374. Email address=schweig@uw.edu.']
# order ID:  5000000320068
# status URL:  https://n5eil02u.ecs.nsidc.org/egi/request/5000000320068
# HTTP response from order response URL:  201
# Data request  1  is submitting...
# Initial request status is  processing
# Status is not complete. Trying again.
# Retry request status is:  complete
# Zip download URL:  https://n5eil02u.ecs.nsidc.org/esir/5000000320068.zip
# Beginning download of zipped output...
# Data request 1 is complete.
# Order:  2
# Request HTTP response:  201
# Order request URL:  https://n5eil02u.ecs.nsidc.org/egi/request?short_name=ATL10&temporal=2018-12-01T00%3A00%3A00Z%2C2018-12-06T23%3A59%3A59Z&bounding_box=-180%2C60%2C-160%2C85&request_mode=async&page_size=20&token=E62B4B88-9593-546B-D952-510D17894DA3&email=schweig%40uw.edu&agent=NO&page_num=2
# esir_root <Element '{http://eosdis.nasa.gov/esi/rsp/e}agentResponse' at 0x7f86c3d3a908>
# Order request response XML content:  b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?>\n<eesi:agentResponse xsi:schemaLocation="http://eosdis.nasa.gov/esi/rsp/e https://newsroom.gsfc.nasa.gov/esi/8.1/schemas/ESIAgentResponseExternal.xsd" xmlns="" xmlns:iesi="http://eosdis.nasa.gov/esi/rsp/i" xmlns:ssw="http://newsroom.gsfc.nasa.gov/esi/rsp/ssw" xmlns:eesi="http://eosdis.nasa.gov/esi/rsp/e" xmlns:esi="http://eosdis.nasa.gov/esi/rsp" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">\n    <order>\n        <orderId>5000000320071</orderId>\n        <Instructions>You may receive an email about your order if you specified an EMAIL address. &lt;br/&gt;&lt;br/&gt;The instructions used to process this order are:  Processing tool=NO. Granule id(s)=SC:ATL10.001:161230239,SC:ATL10.001:161175237,SC:ATL10.001:161227411,SC:ATL10.001:161196369,SC:ATL10.001:161212647,SC:ATL10.001:161208336,SC:ATL10.001:161209636,SC:ATL10.001:161227922,SC:ATL10.001:161214441,SC:ATL10.001:161228270,SC:ATL10.001:161228148,SC:ATL10.001:161228836,SC:ATL10.001:161208341. Email address=schweig@uw.edu.</Instructions>\n    </order>\n    <contactInformation>\n        <contactName>NSIDC User Services</contactName>\n        <contactEmail>nsidc@nsidc.org</contactEmail>\n    </contactInformation>\n    <processInfo>\n        <processDuration>PT0.115S</processDuration>\n        <subagentId>NO</subagentId>\n    </processInfo>\n    <requestStatus>\n        <status>processing</status>\n        <numberProcessed>0</numberProcessed>\n        <totalNumber>13</totalNumber>\n    </requestStatus>\n</eesi:agentResponse>\n'
# Order Look Now:
# Order.Text: 5000000320071
# ['5000000320071']
# Order.Text: You may receive an email about your order if you specified an EMAIL address. <br/><br/>The instructions used to process this order are:  Processing tool=NO. Granule id(s)=SC:ATL10.001:161230239,SC:ATL10.001:161175237,SC:ATL10.001:161227411,SC:ATL10.001:161196369,SC:ATL10.001:161212647,SC:ATL10.001:161208336,SC:ATL10.001:161209636,SC:ATL10.001:161227922,SC:ATL10.001:161214441,SC:ATL10.001:161228270,SC:ATL10.001:161228148,SC:ATL10.001:161228836,SC:ATL10.001:161208341. Email address=schweig@uw.edu.
# ['5000000320071', 'You may receive an email about your order if you specified an EMAIL address. <br/><br/>The instructions used to process this order are:  Processing tool=NO. Granule id(s)=SC:ATL10.001:161230239,SC:ATL10.001:161175237,SC:ATL10.001:161227411,SC:ATL10.001:161196369,SC:ATL10.001:161212647,SC:ATL10.001:161208336,SC:ATL10.001:161209636,SC:ATL10.001:161227922,SC:ATL10.001:161214441,SC:ATL10.001:161228270,SC:ATL10.001:161228148,SC:ATL10.001:161228836,SC:ATL10.001:161208341. Email address=schweig@uw.edu.']
# order ID:  5000000320071
# status URL:  https://n5eil02u.ecs.nsidc.org/egi/request/5000000320071
# HTTP response from order response URL:  201
# Data request  2  is submitting...
# Initial request status is  processing
# Status is not complete. Trying again.
# Retry request status is:  complete
# Zip download URL:  https://n5eil02u.ecs.nsidc.org/esir/5000000320071.zip
# Beginning download of zipped output...
# Data request 2 is complete.

# %%
#Clean up Outputs folder by removing individual granule folders 

print(path)

for root, dirs, files in os.walk(path, topdown=False):
    for file in files:
        try:
            shutil.move(os.path.join(root, file), path)
        except OSError:
            pass
        
for root, dirs, files in os.walk(path):
    for name in dirs:
        print(os.path.join(root, name))
        os.rmdir(os.path.join(root, name))
# Out:
# /home/jovyan/DATA/ATL10
# /home/jovyan/DATA/ATL10/161227922
# /home/jovyan/DATA/ATL10/161226437
# /home/jovyan/DATA/ATL10/161223827
# /home/jovyan/DATA/ATL10/161214441
# /home/jovyan/DATA/ATL10/161225968
# /home/jovyan/DATA/ATL10/143890843
# /home/jovyan/DATA/ATL10/144678589
# /home/jovyan/DATA/ATL10/161226011
# /home/jovyan/DATA/ATL10/161225911
# /home/jovyan/DATA/ATL10/161209636
# /home/jovyan/DATA/ATL10/161175247
# /home/jovyan/DATA/ATL10/161225935
# /home/jovyan/DATA/ATL10/161208341
# /home/jovyan/DATA/ATL10/161226440
# /home/jovyan/DATA/ATL10/161196369
# /home/jovyan/DATA/ATL10/161225900
# /home/jovyan/DATA/ATL10/161225948
# /home/jovyan/DATA/ATL10/161196374
# /home/jovyan/DATA/ATL10/161212647
# /home/jovyan/DATA/ATL10/161225652
# /home/jovyan/DATA/ATL10/161208336
# /home/jovyan/DATA/ATL10/161175237
# /home/jovyan/DATA/ATL10/161228148
# /home/jovyan/DATA/ATL10/161227411
# /home/jovyan/DATA/ATL10/161204128
# /home/jovyan/DATA/ATL10/161225897
# /home/jovyan/DATA/ATL10/161224302
# /home/jovyan/DATA/ATL10/161228836
# /home/jovyan/DATA/ATL10/161204159
# /home/jovyan/DATA/ATL10/161228270
# /home/jovyan/DATA/ATL10/160722641
# /home/jovyan/DATA/ATL10/161223929
# /home/jovyan/DATA/ATL10/161230239
# /home/jovyan/DATA/ATL10/161206731
# /home/jovyan/DATA/ATL10/161183469

# %%
#List files
sorted(os.listdir(path))
# Out:
# []
